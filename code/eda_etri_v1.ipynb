# %%
import numpy as np
import pandas as pd
import os

from matplotlib import pyplot as plt
from matplotlib import colors

# %%
root = "../"
dir_data = root+"EDA/data/"

# %%
df = pd.read_csv(dir_data+"101_402_appliances(real)_and_houseload(cum).csv")

# %%
df
# Out:
#                  Unnamed: 0  PC(침실2)_(W)  PMM(조명)_(W)  TV(거실)_(W)  \
# 0       2021-07-01 00:00:00         52.9         60.0         1.0
# 1       2021-07-01 00:05:00         54.7         66.0         0.9
# 2       2021-07-01 00:10:00         51.1        313.0         1.1
# 3       2021-07-01 00:15:00         57.8        308.0         1.3
# 4       2021-07-01 00:20:00         51.6        305.0         NaN
# ...                     ...          ...          ...         ...
# 105071  2022-06-30 19:55:00          NaN          NaN         NaN
# 105072  2022-06-30 20:00:00          NaN          NaN         NaN
# 105073  2022-06-30 20:05:00          NaN          NaN         NaN
# 105074  2022-06-30 20:10:00          NaN          NaN         NaN
# 105075  2022-06-30 20:15:00          NaN          NaN         NaN
#
#         TV(침실1)_(W)  선풍기1(침실1)_(W)  선풍기2(침실2)_(W)  세탁기(발코니2)_(W)  에어컨(거실)_(W)  \
# 0               0.7            0.6            0.7            0.7          4.4
# 1               NaN            0.0            NaN            0.8          4.5
# 2               0.8            NaN            0.9            0.6          3.3
# 3               NaN            0.8            NaN            NaN          NaN
# 4               NaN            0.9            1.0            NaN          NaN
# ...             ...            ...            ...            ...          ...
# 105071          NaN            NaN            NaN            NaN          NaN
# 105072          NaN            NaN            NaN            NaN          NaN
# 105073          NaN            NaN            NaN            NaN          NaN
# 105074          NaN            NaN            NaN            NaN          NaN
# 105075          NaN            NaN            NaN            NaN          NaN
#
#         에어컨실외기(거실)_(W)  에어프라이기(주방)_(W)  전기밥솥(주방)_(W)  전자레인지(주방)_(W)  \
# 0                  0.8             0.3         702.3            1.2
# 1                  0.6             0.6          85.0            0.1
# 2                  NaN             NaN          85.5            0.3
# 3                  NaN             NaN          85.2            0.2
# 4                  NaN             NaN          85.6            0.0
# ...                ...             ...           ...            ...
# 105071             NaN             NaN           NaN            NaN
# 105072             NaN             NaN           NaN            NaN
# 105073             NaN             NaN           NaN            NaN
# 105074             NaN             NaN           NaN            NaN
# 105075             NaN             NaN         414.8            NaN
#
#         커피포트(주방)_(W)  헤어드라이어(침실1)_(W)  cummulative_power_this_month(kWh)
# 0                0.5              0.8                              0.000
# 1                0.7              NaN                                NaN
# 2                0.6              NaN                                NaN
# 3                NaN              NaN                              0.090
# 4                NaN              NaN                                NaN
# ...              ...              ...                                ...
# 105071           NaN              NaN                                NaN
# 105072           NaN              NaN                            403.794
# 105073           NaN              NaN                                NaN
# 105074           NaN              NaN                                NaN
# 105075           NaN              NaN                            404.079
#
# [105076 rows x 16 columns]

# %%
hems_data = df.values[:,:15]

# %%
hems_data
# Out:
# array([['2021-07-01 00:00:00', 52.9, 60.0, ..., 1.2, 0.5, 0.8],
#        ['2021-07-01 00:05:00', 54.7, 66.0, ..., 0.1, 0.7, nan],
#        ['2021-07-01 00:10:00', 51.1, 313.0, ..., 0.3, 0.6, nan],
#        ...,
#        ['2022-06-30 20:05:00', nan, nan, ..., nan, nan, nan],
#        ['2022-06-30 20:10:00', nan, nan, ..., nan, nan, nan],
#        ['2022-06-30 20:15:00', nan, nan, ..., nan, nan, nan]],
#       dtype=object)
